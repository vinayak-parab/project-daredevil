# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
import torchaudio

# %%
root_dir = "/work/oarongve/data/sound_dataset/SoccerNet-code/data/"
train_file = root_dir+"listgame_Train_300.npy"
valid_file = root_dir+"listgame_Valid_100.npy"
test_file = root_dir+"listgame_Test_100.npy"

# %% [markdown]
# # Librosa test

# %%
import librosa
import matplotlib.pyplot as plt

# %%
SAMPLE_RATE = 8000 # Should be 16 kHz
WINDOW_LENGTH = int(0.025 * SAMPLE_RATE) # Should be 25 ms
N_FFT = 512 # Should be 512
STEP_SIZE = int(0.01 * SAMPLE_RATE) # Should be 10ms

# %%
# Clip dataset
from torch.utils.data import Dataset, DataLoader
import numpy as np
import torch
import os
import json
import torchvision
import datetime
import torchaudio
import librosa
from subprocess import Popen, PIPE
import re



class SoccerNetDataset(Dataset):
    """Soccernet Dataset"""
    
    SAMPLE_RATE = 8000 # Should be 16 kHz
    WINDOW_LENGTH = int(0.025 * SAMPLE_RATE) # Should be 25 ms
    N_FFT = 512 # Should be 512
    STEP_SIZE = int(0.01 * SAMPLE_RATE) # Should be 10ms
    
    def __init__(self,npy_file,
                 root_dir,
                 transform=None,
                 background=False,
                 wsize=4):
    
        self.wsize = wsize
        self.npy_file = np.load(npy_file)
        self.samples = list() # maybe change structure later depending on efficiency        
        self.root_dir = root_dir
        self.transform = transform

        for e in self.npy_file:
            path, annotations = self.get_annotations(e)

            duration1 = self.getVideoLength(self.root_dir + e + "/1.mkv")
            duration2 = self.getVideoLength(self.root_dir + e + "/2.mkv")
            #print(f"duration1 : {duration1}, duration2: {duration2}")
            for annotation in annotations:
                # Check that annotations hold correct labels
                        if ("card" in annotation["label"]) or ("subs" in annotation["label"]) or ("soccer" in annotation["label"]):
                            annotation["duration1"] = duration1
                            annotation["duration2"] = duration2
                            self.samples.append([path,annotation])

       
    def __len__(self):
        return len(self.samples)
    
    def getVideoLength(self,video_file):
        res = Popen(['ffmpeg', '-i', video_file, '-hide_banner'],stdout=PIPE,stderr=PIPE)
        none,meta = res.communicate()
        meta_out = meta.decode()
        #---| Take out info
        duration = re.search(r'Duration:.*', meta_out)
        return duration.group()[:21]

    def __getitem__(self,idx):
        """Returns a sample containing video path, clip and label"""
        if torch.is_tensor(idx):
            idx.tolist()
        
        # get annotations
        time_half = int(self.samples[idx][1]["gameTime"][0])
        time_minute = int(self.samples[idx][1]["gameTime"][-5:-3])
        time_second = int(self.samples[idx][1]["gameTime"][-2:])
        annotation = self.samples[idx][1]

        # Get label
        if ("card" in annotation["label"]): label = 0
        elif ("subs" in annotation["label"]): label = 1
        elif ("soccer" in annotation["label"]): label = 2
        elif ("background" in annotation["label"]): label = 3
        else: 
            print("Warning, label not compatible with set")
            return

        # Get audiopath
        audiopath = os.path.join(self.root_dir,
                              str(self.samples[idx][0]),
                                str(time_half)+"_audio.wav")
        

        
        one_hot_label = np.zeros(4)
        one_hot_label[label] = 1
        # Get video frames 
        
        # get start in second, use labeled time as center TODO: fix centerframe as keyframe and stride
        fps = 25.0 # assume fps = 25 for now, should be so
        start_sec = time_minute*60 + time_second
        end_sec = start_sec
        
        if start_sec == 0:
            end_sec += (1/fps) # possibly unstable solution
            
        end_sec = end_sec + self.wsize # might need to subtract 1/fps
        # Shift backwards to center around time but check that time > 0
        diff = (end_sec - start_sec) / 2 # TODO : Might result in bad precision
        temp_start_sec = start_sec - diff
        temp_end_sec = end_sec - diff

        # Only change as long as the shift operation doesnt shift out of bounds 
        if temp_start_sec >= 0:
            start_sec = temp_start_sec
            end_sec = temp_end_sec
        
        # Buffer to endsec incase of bad load
        end_sec = end_sec + 0.9 # loads more frames than needed, then reduced later
        
        y, sr = librosa.load(audiopath,sr=SAMPLE_RATE,offset=start_sec,duration=self.wsize+1)
        
        print(len(y))
        y = y[:SAMPLE_RATE*4]
        
        ms = torchaudio.transforms.MelSpectrogram(sample_rate=SAMPLE_RATE,
                                                n_fft=N_FFT,
                                                win_length=WINDOW_LENGTH,
                                                hop_length=STEP_SIZE)(torch.Tensor(y)).log10().unsqueeze(0)
        print(f"ms size = {ms.size()}")
        
        
        ms = ms[:,:,:401]
        if ms.size() != (1,128,401):
            print(f"ms size :{ms.size()}, using zeros instead ...")
            ms = torch.zeros((1,128,401))
        
        sample = {'audiopath': audiopath, 'annotation':annotation,'idx':idx,'audio':y,'sr':sr,'mel_spectogram':ms, 'one_hot_label':one_hot_label,'label':label}
        
        return sample
            
    def get_annotations(self,path):
        """ Reads json files and returns """
        with open(self.root_dir+path+"/Labels.json") as jsonfile:
            json_label = json.load(jsonfile)
        
        labels = [e for e in json_label['annotations']]
        
        return path,labels
    def get_keyframe(self,idx):
        if self.frame_center == 'back': return self.__getitem__(idx)['clip'][0,:,:,:]
        elif self.frame_center == 'center': return self.__getitem__(idx)['clip'][self.nframes//2,:,:,:]
        elif self.frame_center == 'front': return self.__getitem__(idx)['clip'][self.nframes-1,:,:,:]
    def describe(self):
        card = 0
        subs = 0
        goal = 0
        background = 0

        for sample in self.samples:
            annotation = sample[1]
        # Get label
            if ("card" in annotation["label"]): card += 1
            elif ("subs" in annotation["label"]): subs +=1
            elif ("soccer" in annotation["label"]): goal += 1
            elif ("background" in annotation["label"]): background += 1

        print("Description of dataset\n\n")
        print("\n ********* Classes *********")
        print("\n card = 0\n subs = 1\n goals = 2\n background = 3")

        print("\n ********* Distribution and count *********")
        print(f"\n N card: {card} \n N subs: {subs} \n N goal: {goal} \n N background: {background} \n \n Total : {card+subs+goal+background}")
        
        print("\n\n ********* Configuration *********")
        print(f"\n npy_file: {self.npy_file} \n tshift: {self.tshift} \n root_dir: {self.root_dir} \n transform: {self.transform} \n frame_center: {self.frame_center} \n nframes: {self.nframes} \n stride_frames: {self.stride_frames} \n background: {self.background}")
        print("\n\n ********* End of description *********")

# %%
X = SoccerNetDataset(root_dir=root_dir,npy_file=train_file)

# %%
# Disable warnings
import warnings
warnings.filterwarnings('ignore')

# %%
for e in X:
    print(e['mel_spectogram'].size())
# Out:
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# 40000
# ms size = torch.Size([1, 128, 401])
# torch.Size([1, 128, 401])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/.local/share/virtualenvs/project-daredevil-8eBKzQn6/lib/python3.6/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     145     try:
# --> 146         with sf.SoundFile(path) as sf_desc:
#     147             sr_native = sf_desc.samplerate
#
# ~/.local/share/virtualenvs/project-daredevil-8eBKzQn6/lib/python3.6/site-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ~/.local/share/virtualenvs/project-daredevil-8eBKzQn6/lib/python3.6/site-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1183         _error_check(_snd.sf_error(file_ptr),
# -> 1184                      "Error opening {0!r}: ".format(self.name))
#    1185         if mode_int == _snd.SFM_WRITE:
#
# ~/.local/share/virtualenvs/project-daredevil-8eBKzQn6/lib/python3.6/site-packages/soundfile.py in _error_check(err, prefix)
#    1356         err_str = _snd.sf_error_number(err)
# -> 1357         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1358
#
# RuntimeError: Error opening '/work/oarongve/data/sound_dataset/SoccerNet-code/data/europe_uefa-champions-league/2014-2015/2014-12-09 - 22-45 Liverpool 1 - 1 Basel/2_audio.wav': Error in WAV/W64/RF64 file. Malformed 'fmt ' chunk.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8290a52361a4> in <module>
# ----> 1 for e in X:
#       2     print(e['mel_spectogram'].size())
#
# <ipython-input-5-a5bcf842e0ad> in __getitem__(self, idx)
#     112         end_sec = end_sec + 0.9 # loads more frames than needed, then reduced later
#     113
# --> 114         y, sr = librosa.load(audiopath,sr=SAMPLE_RATE,offset=start_sec,duration=self.wsize+1)
#     115
#     116         print(len(y))
#
# ~/.local/share/virtualenvs/project-daredevil-8eBKzQn6/lib/python3.6/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     161         if isinstance(path, (str, pathlib.PurePath)):
#     162             warnings.warn("PySoundFile failed. Trying audioread instead.")
# --> 163             y, sr_native = __audioread_load(path, offset, duration, dtype)
#     164         else:
#     165             raise (exc)
#
# ~/.local/share/virtualenvs/project-daredevil-8eBKzQn6/lib/python3.6/site-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     198         n = 0
#     199
# --> 200         for frame in input_file:
#     201             frame = util.buf_to_float(frame, dtype=dtype)
#     202             n_prev = n
#
# ~/.local/share/virtualenvs/project-daredevil-8eBKzQn6/lib/python3.6/site-packages/audioread/ffdec.py in read_data(self, timeout)
#     189             data = None
#     190             try:
# --> 191                 data = self.stdout_reader.queue.get(timeout=timeout)
#     192                 if data:
#     193                     yield data
#
# /usr/lib/python3.6/queue.py in get(self, block, timeout)
#     171                     if remaining <= 0.0:
#     172                         raise Empty
# --> 173                     self.not_empty.wait(remaining)
#     174             item = self._get()
#     175             self.not_full.notify()
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
params = {'batch_size': 8,
         'shuffle': False,
         'num_workers':4}

# %%
dataloader = DataLoader(X,**params)

# %%
# %%bash
# nvidia-smi

# %% [markdown]
# # Save to numpy

# %%
# Clip dataset
from torch.utils.data import Dataset, DataLoader
import numpy as np
import torch
import os
import json
import torchvision
import datetime
import torchaudio
import librosa
from subprocess import Popen, PIPE
import re



class SoccerNetDataset(Dataset):
    """Soccernet Dataset"""
    
    SAMPLE_RATE = 8000 # Should be 16 kHz
    WINDOW_LENGTH = int(0.025 * SAMPLE_RATE) # Should be 25 ms
    N_FFT = 512 # Should be 512
    STEP_SIZE = int(0.01 * SAMPLE_RATE) # Should be 10ms
    
    def __init__(self,npy_file,
                 root_dir,
                 transform=None,
                 background=False,
                 wsize=4):
    
        self.wsize = wsize
        self.npy_file = np.load(npy_file)
        self.samples = list() # maybe change structure later depending on efficiency        
        self.root_dir = root_dir
        self.transform = transform

        for e in self.npy_file:
            path, annotations = self.get_annotations(e)

            duration1 = self.getVideoLength(self.root_dir + e + "/1.mkv")
            duration2 = self.getVideoLength(self.root_dir + e + "/2.mkv")
            #print(f"duration1 : {duration1}, duration2: {duration2}")
            for annotation in annotations:
                # Check that annotations hold correct labels
                        if ("card" in annotation["label"]) or ("subs" in annotation["label"]) or ("soccer" in annotation["label"]):
                            annotation["duration1"] = duration1
                            annotation["duration2"] = duration2
                            self.samples.append([path,annotation])

       
    def __len__(self):
        return len(self.samples)
    
    def getVideoLength(self,video_file):
        res = Popen(['ffmpeg', '-i', video_file, '-hide_banner'],stdout=PIPE,stderr=PIPE)
        none,meta = res.communicate()
        meta_out = meta.decode()
        #---| Take out info
        duration = re.search(r'Duration:.*', meta_out)
        return duration.group()[:21]

    def __getitem__(self,idx):
        """Returns a sample containing video path, clip and label"""
        if torch.is_tensor(idx):
            idx.tolist()
        
        # get annotations
        time_half = int(self.samples[idx][1]["gameTime"][0])
        time_minute = int(self.samples[idx][1]["gameTime"][-5:-3])
        time_second = int(self.samples[idx][1]["gameTime"][-2:])
        annotation = self.samples[idx][1]

        # Get label
        if ("card" in annotation["label"]): label = 0
        elif ("subs" in annotation["label"]): label = 1
        elif ("soccer" in annotation["label"]): label = 2
        elif ("background" in annotation["label"]): label = 3
        else: 
            print("Warning, label not compatible with set")
            return

        # Get audiopath
        audiopath = os.path.join(self.root_dir,
                              str(self.samples[idx][0]),
                                str(time_half)+"_audio.wav")
        

        
        one_hot_label = np.zeros(4)
        one_hot_label[label] = 1
        # Get video frames 
        
        # get start in second, use labeled time as center TODO: fix centerframe as keyframe and stride
        fps = 25.0 # assume fps = 25 for now, should be so
        start_sec = time_minute*60 + time_second
        end_sec = start_sec
        
        if start_sec == 0:
            end_sec += (1/fps) # possibly unstable solution
            
        end_sec = end_sec + self.wsize # might need to subtract 1/fps
        # Shift backwards to center around time but check that time > 0
        diff = (end_sec - start_sec) / 2 # TODO : Might result in bad precision
        temp_start_sec = start_sec - diff
        temp_end_sec = end_sec - diff

        # Only change as long as the shift operation doesnt shift out of bounds 
        if temp_start_sec >= 0:
            start_sec = temp_start_sec
            end_sec = temp_end_sec
        
        # Buffer to endsec incase of bad load
        end_sec = end_sec + 0.9 # loads more frames than needed, then reduced later
        """
        y, sr = librosa.load(audiopath,sr=SAMPLE_RATE,offset=start_sec,duration=self.wsize+1)
        
        print(len(y))
        y = y[:SAMPLE_RATE*4]
        
        ms = torchaudio.transforms.MelSpectrogram(sample_rate=SAMPLE_RATE,
                                                n_fft=N_FFT,
                                                win_length=WINDOW_LENGTH,
                                                hop_length=STEP_SIZE)(torch.Tensor(y)).log10().unsqueeze(0)
        print(f"ms size = {ms.size()}")
        
        
        ms = ms[:,:,:401]
        if ms.size() != (1,128,401):
            print(f"ms size :{ms.size()}, using zeros instead ...")
            ms = torch.zeros((1,128,401))
        """
        
        sample = {'audiopath': audiopath, 'annotation':annotation,'idx':idx, 'one_hot_label':one_hot_label,'label':label}
        
        return sample
            
    def get_annotations(self,path):
        """ Reads json files and returns """
        with open(self.root_dir+path+"/Labels.json") as jsonfile:
            json_label = json.load(jsonfile)
        
        labels = [e for e in json_label['annotations']]
        
        return path,labels
    def get_keyframe(self,idx):
        if self.frame_center == 'back': return self.__getitem__(idx)['clip'][0,:,:,:]
        elif self.frame_center == 'center': return self.__getitem__(idx)['clip'][self.nframes//2,:,:,:]
        elif self.frame_center == 'front': return self.__getitem__(idx)['clip'][self.nframes-1,:,:,:]
    def describe(self):
        card = 0
        subs = 0
        goal = 0
        background = 0

        for sample in self.samples:
            annotation = sample[1]
        # Get label
            if ("card" in annotation["label"]): card += 1
            elif ("subs" in annotation["label"]): subs +=1
            elif ("soccer" in annotation["label"]): goal += 1
            elif ("background" in annotation["label"]): background += 1

        print("Description of dataset\n\n")
        print("\n ********* Classes *********")
        print("\n card = 0\n subs = 1\n goals = 2\n background = 3")

        print("\n ********* Distribution and count *********")
        print(f"\n N card: {card} \n N subs: {subs} \n N goal: {goal} \n N background: {background} \n \n Total : {card+subs+goal+background}")
        
        print("\n\n ********* Configuration *********")
        print(f"\n npy_file: {self.npy_file} \n tshift: {self.tshift} \n root_dir: {self.root_dir} \n transform: {self.transform} \n frame_center: {self.frame_center} \n nframes: {self.nframes} \n stride_frames: {self.stride_frames} \n background: {self.background}")
        print("\n\n ********* End of description *********")

# %%
X = SoccerNetDataset(root_dir=root_dir,npy_file=train_file)

# %%
X[0]
# Out:
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/1_audio.wav',
#  'annotation': {'gameTime': '1 - 13:10',
#   'label': 'soccer-ball',
#   'team': 'home',
#   'duration1': 'Duration: 00:45:00.00',
#   'duration2': 'Duration: 00:45:00.00'},
#  'idx': 0,
#  'one_hot_label': array([0., 0., 1., 0.]),
#  'label': 2}

# %%
samples = list()
for e in X:
    samples.append(e)

# %%
np.save(file=root_dir+"train_samples.npy",arr=samples,allow_pickle=True)

# %%
s = np.load(root_dir+"train_samples.npy",allow_pickle=True)

# %%
samples

# %%
for k in samples:
    print(k)
# Out:
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/1_audio.wav', 'annotation': {'gameTime': '1 - 13:10', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 0, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/1_audio.wav', 'annotation': {'gameTime': '1 - 40:08', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 1, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/2_audio.wav', 'annotation': {'gameTime': '2 - 17:02', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 2, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/2_audio.wav', 'annotation': {'gameTime': '2 - 17:18', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/2_audio.wav', 'annotation': {'gameTime': '2 - 24:26', 'label': 'r-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 4, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/2_audio.wav', 'annotation': {'gameTime': '2 - 25:06', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 5, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/2_audio.wav', 'annotation': {'gameTime': '2 - 26:10', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 6, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/2_audio.wav', 'annotation': {'gameTime': '2 - 33:21', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 7, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/2_audio.wav', 'annotation': {'gameTime': '2 - 35:21', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 8, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/2_audio.wav', 'annotation': {'gameTime': '2 - 39:54', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 9, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/1_audio.wav', 'annotation': {'gameTime': '1 - 07:06', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 10, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/1_audio.wav', 'annotation': {'gameTime': '1 - 18:33', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 11, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/1_audio.wav', 'annotation': {'gameTime': '1 - 27:44', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 12, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/1_audio.wav', 'annotation': {'gameTime': '1 - 45:07', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 13, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/2_audio.wav', 'annotation': {'gameTime': '2 - 10:24', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 14, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/2_audio.wav', 'annotation': {'gameTime': '2 - 11:58', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 15, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/2_audio.wav', 'annotation': {'gameTime': '2 - 30:40', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 16, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/2_audio.wav', 'annotation': {'gameTime': '2 - 31:03', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 17, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/2_audio.wav', 'annotation': {'gameTime': '2 - 33:46', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 18, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/2_audio.wav', 'annotation': {'gameTime': '2 - 34:10', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 19, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/2_audio.wav', 'annotation': {'gameTime': '2 - 39:05', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 20, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/2_audio.wav', 'annotation': {'gameTime': '2 - 43:34', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 21, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/2_audio.wav', 'annotation': {'gameTime': '2 - 48:34', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:46:07.00', 'duration2': 'Duration: 00:49:34.00'}, 'idx': 22, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/1_audio.wav', 'annotation': {'gameTime': '1 - 27:36', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 23, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/1_audio.wav', 'annotation': {'gameTime': '1 - 29:32', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 24, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/1_audio.wav', 'annotation': {'gameTime': '1 - 44:25', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 25, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 00:00', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 26, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 02:43', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 27, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 12:54', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 28, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 27:07', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 29, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 28:35', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 30, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 33:10', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 31, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 38:47', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 32, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 42:01', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 33, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 42:44', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 34, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 45:17', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 35, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/2_audio.wav', 'annotation': {'gameTime': '2 - 47:57', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:25.00', 'duration2': 'Duration: 00:48:57.00'}, 'idx': 36, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/1_audio.wav', 'annotation': {'gameTime': '1 - 02:32', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 37, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/1_audio.wav', 'annotation': {'gameTime': '1 - 42:42', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 38, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 00:00', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 39, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 00:00', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 40, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 11:01', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 41, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 16:56', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 42, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 17:55', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 43, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 27:49', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 44, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 29:00', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 45, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 29:14', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 46, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 32:02', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 47, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 38:51', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 48, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/2_audio.wav', 'annotation': {'gameTime': '2 - 45:41', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:46:41.00'}, 'idx': 49, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/1_audio.wav', 'annotation': {'gameTime': '1 - 18:00', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 50, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/1_audio.wav', 'annotation': {'gameTime': '1 - 22:09', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 51, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/1_audio.wav', 'annotation': {'gameTime': '1 - 28:16', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 52, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/1_audio.wav', 'annotation': {'gameTime': '1 - 29:48', 'label': 'soccer-ball-own', 'team': 'home', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 53, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/1_audio.wav', 'annotation': {'gameTime': '1 - 41:02', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 54, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/1_audio.wav', 'annotation': {'gameTime': '1 - 46:25', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 55, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/2_audio.wav', 'annotation': {'gameTime': '2 - 06:45', 'label': 'r-card', 'team': 'home', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 56, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/2_audio.wav', 'annotation': {'gameTime': '2 - 08:01', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 57, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/2_audio.wav', 'annotation': {'gameTime': '2 - 08:32', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 58, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/2_audio.wav', 'annotation': {'gameTime': '2 - 09:04', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 59, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/2_audio.wav', 'annotation': {'gameTime': '2 - 25:41', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 60, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/2_audio.wav', 'annotation': {'gameTime': '2 - 30:26', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 61, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/2_audio.wav', 'annotation': {'gameTime': '2 - 33:39', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 62, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/2_audio.wav', 'annotation': {'gameTime': '2 - 38:17', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 63, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/2_audio.wav', 'annotation': {'gameTime': '2 - 47:34', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:47:25.00', 'duration2': 'Duration: 00:48:34.00'}, 'idx': 64, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 09:55', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 65, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 19:33', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 66, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 20:47', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 67, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 22:49', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 68, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 25:44', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 69, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 27:06', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 70, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 27:21', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 71, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 33:42', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 72, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 35:30', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 73, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 36:37', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 74, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/2_audio.wav', 'annotation': {'gameTime': '2 - 38:32', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 75, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/1_audio.wav', 'annotation': {'gameTime': '1 - 39:22', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 76, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/1_audio.wav', 'annotation': {'gameTime': '1 - 42:59', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 77, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/2_audio.wav', 'annotation': {'gameTime': '2 - 00:00', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 78, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/2_audio.wav', 'annotation': {'gameTime': '2 - 01:28', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 79, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/2_audio.wav', 'annotation': {'gameTime': '2 - 10:09', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 80, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/2_audio.wav', 'annotation': {'gameTime': '2 - 17:00', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 81, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/2_audio.wav', 'annotation': {'gameTime': '2 - 17:49', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 82, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/2_audio.wav', 'annotation': {'gameTime': '2 - 26:29', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 83, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/2_audio.wav', 'annotation': {'gameTime': '2 - 29:12', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 84, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/2_audio.wav', 'annotation': {'gameTime': '2 - 30:33', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 85, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-08-29 - 17-00 Manchester City 2 - 0 Watford/2_audio.wav', 'annotation': {'gameTime': '2 - 43:04', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 86, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/1_audio.wav', 'annotation': {'gameTime': '1 - 08:33', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 87, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/1_audio.wav', 'annotation': {'gameTime': '1 - 16:17', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 88, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/1_audio.wav', 'annotation': {'gameTime': '1 - 21:20', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 89, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/1_audio.wav', 'annotation': {'gameTime': '1 - 35:10', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 90, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 09:53', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 91, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 19:18', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 92, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 24:08', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 93, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 26:30', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 94, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 28:49', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 95, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 31:25', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 96, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 36:55', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 97, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 41:02', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 98, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 42:20', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 99, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 14-45 Everton 3 - 1 Chelsea/2_audio.wav', 'annotation': {'gameTime': '2 - 47:03', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:48:03.00'}, 'idx': 100, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/1_audio.wav', 'annotation': {'gameTime': '1 - 17:23', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 101, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/1_audio.wav', 'annotation': {'gameTime': '1 - 24:28', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 102, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/1_audio.wav', 'annotation': {'gameTime': '1 - 25:29', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 103, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/2_audio.wav', 'annotation': {'gameTime': '2 - 22:07', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 104, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/2_audio.wav', 'annotation': {'gameTime': '2 - 23:41', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 105, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/2_audio.wav', 'annotation': {'gameTime': '2 - 25:33', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 106, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/2_audio.wav', 'annotation': {'gameTime': '2 - 34:30', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 107, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/2_audio.wav', 'annotation': {'gameTime': '2 - 35:16', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 108, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/2_audio.wav', 'annotation': {'gameTime': '2 - 37:09', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 109, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/2_audio.wav', 'annotation': {'gameTime': '2 - 44:00', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 110, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/2_audio.wav', 'annotation': {'gameTime': '2 - 44:33', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 111, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-12 - 17-00 Crystal Palace 0 - 1 Manchester City/2_audio.wav', 'annotation': {'gameTime': '2 - 48:35', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:35.00'}, 'idx': 112, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/1_audio.wav', 'annotation': {'gameTime': '1 - 05:20', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 113, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/1_audio.wav', 'annotation': {'gameTime': '1 - 21:41', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 114, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/1_audio.wav', 'annotation': {'gameTime': '1 - 30:45', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 115, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/1_audio.wav', 'annotation': {'gameTime': '1 - 46:12', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 116, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/1_audio.wav', 'annotation': {'gameTime': '1 - 49:03', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 117, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/2_audio.wav', 'annotation': {'gameTime': '2 - 00:00', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 118, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/2_audio.wav', 'annotation': {'gameTime': '2 - 08:08', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 119, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/2_audio.wav', 'annotation': {'gameTime': '2 - 14:37', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 120, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/2_audio.wav', 'annotation': {'gameTime': '2 - 20:18', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 121, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/2_audio.wav', 'annotation': {'gameTime': '2 - 23:51', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 122, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/2_audio.wav', 'annotation': {'gameTime': '2 - 38:47', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 123, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-19 - 19-30 Manchester City 1 - 2 West Ham/2_audio.wav', 'annotation': {'gameTime': '2 - 39:39', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:50:03.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 124, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa/1_audio.wav', 'annotation': {'gameTime': '1 - 01:03', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:02.00'}, 'idx': 125, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa/2_audio.wav', 'annotation': {'gameTime': '2 - 12:58', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:02.00'}, 'idx': 126, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/england_epl/2015-2016/2015-09-26 - 17-00 Liverpool 3 - 2 Aston Villa/2_audio.wav', 'annotation': {'gameTime': '2 - 14:11', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:49:02.00'}, 'idx': 127, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# ...
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 02:22', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3923, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 16:43', 'label': 'yr-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3924, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 18:27', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3925, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 20:27', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3926, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 23:17', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3927, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 24:41', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3928, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 26:01', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3929, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 26:53', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3930, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 27:16', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3931, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 34:26', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3932, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 38:26', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3933, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 38:36', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3934, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 39:35', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3935, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 39:38', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3936, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 40:22', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3937, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-17 - 22-00 Celta Vigo 1 - 4 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 42:31', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3938, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/1_audio.wav', 'annotation': {'gameTime': '1 - 06:45', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3939, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/1_audio.wav', 'annotation': {'gameTime': '1 - 18:41', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3940, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/1_audio.wav', 'annotation': {'gameTime': '1 - 29:38', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3941, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/1_audio.wav', 'annotation': {'gameTime': '1 - 41:00', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3942, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 00:00', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3943, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 08:20', 'label': 'y-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3944, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 15:22', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3945, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 17:37', 'label': 'soccer-ball-own', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3946, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 21:50', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3947, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 25:03', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3948, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 27:49', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3949, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 28:58', 'label': 'yr-card', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3950, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 29:56', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3951, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 30:59', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3952, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 36:55', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3953, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Barcelona 4 - 2 Eibar/2_audio.wav', 'annotation': {'gameTime': '2 - 46:14', 'label': 'soccer-ball', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:47:14.00'}, 'idx': 3954, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/1_audio.wav', 'annotation': {'gameTime': '1 - 01:37', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3955, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 09:38', 'label': 'soccer-ball', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3956, 'one_hot_label': array([0., 0., 1., 0.]), 'label': 2}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 10:07', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3957, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 11:12', 'label': 'y-card', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3958, 'one_hot_label': array([1., 0., 0., 0.]), 'label': 0}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 14:41', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3959, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 20:38', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3960, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 20:50', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3961, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 23:41', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3962, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 26:21', 'label': 'substitution-in', 'team': 'home', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3963, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}
# {'audiopath': '/work/oarongve/data/sound_dataset/SoccerNet-code/data/spain_laliga/2016-2017/2017-05-21 - 21-00 Malaga 0 - 2 Real Madrid/2_audio.wav', 'annotation': {'gameTime': '2 - 27:39', 'label': 'substitution-in', 'team': 'away', 'duration1': 'Duration: 00:45:00.00', 'duration2': 'Duration: 00:45:00.00'}, 'idx': 3964, 'one_hot_label': array([0., 1., 0., 0.]), 'label': 1}

# %% [markdown]
# # Simple network

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.bn1 = nn.BatchNorm2d(6)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.bn2 = nn.BatchNorm2d(16)
        self.pool = nn.MaxPool2d(4, 4)
        self.fc1 = nn.Linear(2208, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 4)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = x.view(-1, 2208)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.0001, momentum=0.9)

# %%
# Disable warnings
import warnings
warnings.filterwarnings('ignore')

# Note: Can also see warning once
# warnings.filterwarnings(action='once')

# %%
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter('runs/mel_spec_experiment_4')

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)

# %%
outputs

# %%
(labels == torch.argmax(outputs, dim=1)).sum()

# %%
labels

# %%
torch.argmax(outputs, dim=1)

# %%
len(dataloader)

# %%
writer = SummaryWriter('runs/mel_spec_experiment_4')

# %%
net.to(device)
# Dataloader or dataset faulty(returns batches of 0
epochs = 2
for epoch in range(epochs):
    running_loss = 0.0
    
    net.train()
    for i, data in enumerate(dataloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data['mel_spectogram'].to(device),data['label'].to(device)

        #print(inputs.size())
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # print statistics
        running_loss += loss.item()
        if i % 5 == 0:    # print every 2000 mini-batches
            
            writer.add_scalar('training loss',
                            running_loss / 5,
                            epoch * len(dataloader) + i)
            
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 5))
            running_loss = 0.0
    
    # calculate accuracy
    with torch.no_grad():
        net.eval()
        res = torch.zeros((3,3))
        for i, data in enumerate(dataloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data['mel_spectogram'].to(device),data['label'].to(device)

            # forward + backward + optimize
            outputs = net(inputs)
            
            preds = torch.argmax(outputs,dim=1)
            
            for p,gt in zip(preds,labels):
                res[int(p),int(gt)] += 1
            

        

        N_total = res.sum()
        N_correct = res.diag().sum()
        
        acc = N_total / N_correct
        
        writer.add_scalar('training acc',
                    acc,
                    epoch)
        print(f"Epoch : {epoch}, Accuracy : {acc}")
        
print('Finished Training')

# %%
writer.close()

# %% [markdown]
# # Evaluate samples to look for cases where y, sr from librosa is inconsistent

# %%
outputs = net(inputs)

# %%
inputs.size()

# %%
net.fc1.weight

# %% [markdown]
# # With GPU

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
net.to(device)

running_loss = 0.0
for i, data in enumerate(dataloader, 0):
    # get the inputs; data is a list of [inputs, labels]
    inputs, labels = data['mel_spectogram'].unsqueeze(0).to(device),torch.argmax(data['one_hot_label']).to(device)

    # zero the parameter gradients
    optimizer.zero_grad()

    # forward + backward + optimize
    outputs = net(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    # print statistics
    running_loss += loss.item()
    if i % 2000 == 1999:    # print every 2000 mini-batches
        print('[%d, %5d] loss: %.3f' %
              (epoch + 1, i + 1, running_loss / 2000))
        running_loss = 0.0

print('Finished Training')

# %%
# %%bash
# nvidia-smi
