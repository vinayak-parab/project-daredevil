# %%
import torch
import torchaudio
import matplotlib.pyplot as plt

# %%
filename = "/hdd/sound_sn/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/1_audio.wav"
waveform, sample_rate = torchaudio.load(filename)

print("Shape of waveform: {}".format(waveform.size()))
print("Sample rate of waveform: {}".format(sample_rate))

#plt.figure()
#plt.plot(waveform.t().numpy())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-28962e4c05eb> in <module>
#       1 filename = "/hdd/sound_sn/SoccerNet-code/data/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/1_audio.wav"
# ----> 2 waveform, sample_rate = torchaudio.load(filename)
#       3
#       4 print("Shape of waveform: {}".format(waveform.size()))
#       5 print("Sample rate of waveform: {}".format(sample_rate))
#
# ~/.local/share/virtualenvs/project_pheonix-oslo-met-Ijx8V06Q/lib/python3.6/site-packages/torchaudio/backend/sox_backend.py in load(filepath, out, normalization, channels_first, num_frames, offset, signalinfo, encodinginfo, filetype)
#      54         signalinfo,
#      55         encodinginfo,
# ---> 56         filetype
#      57     )
#      58
#
# RuntimeError: Error opening audio file

# %%
torchaudio.load
# Out:
# <function torchaudio.backend.sox_backend.load(filepath:str, out:Union[torch.Tensor, NoneType]=None, normalization:bool=True, channels_first:bool=True, num_frames:int=0, offset:int=0, signalinfo:torchaudio.backend.common.SignalInfo=None, encodinginfo:torchaudio.backend.common.EncodingInfo=None, filetype:Union[str, NoneType]=None) -> Tuple[torch.Tensor, int]>

# %%
# %%bash
# pip freeze
# Out:
# absl-py==0.8.1
# apex==0.1
# apturl==0.5.2
# asn1crypto==0.24.0
# astor==0.8.0
# astroid==2.3.3
# attrs==19.3.0
# autopep8==1.4.4
# av==6.2.0
# bleach==2.1.2
# blinker==1.4
# Brlapi==0.6.6
# cachetools==3.1.1
# certifi==2019.11.28
# chardet==3.0.4
# command-not-found==0.3
# config-with-yaml==0.1.0
# cryptography==2.1.4
# cupshelpers==1.0
# cxxfilt==0.2.0
# cycler==0.10.0
# decorator==4.4.1
# defer==1.0.6
# distro-info===0.18ubuntu0.18.04.1
# eduvpn-client==1.1
# entrypoints==0.2.3.post1
# ffmpy==0.2.2
# filelock==3.0.12
# future==0.18.2
# fvcore==0.1
# gast==0.2.2
# gdown==3.8.3
# google-auth==1.7.1
# google-auth-oauthlib==0.4.1
# google-pasta==0.1.8
# grpcio==1.25.0
# h5py==2.10.0
# html5lib==0.999999999
# httplib2==0.9.2
# idna==2.6
# imageio==2.6.1
# importlib-metadata==1.3.0
# ipykernel==4.8.2
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipywidgets==6.0.0
# isort==4.3.21
# Jinja2==2.10
# joblib==0.14.1
# jsonschema==2.6.0
# jupyter-client==5.2.2
# jupyter-core==4.4.0
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# keyring==10.6.0
# keyrings.alt==3.0
# kiwisolver==1.1.0
# language-selector==0.1
# launchpadlib==1.10.6
# lazr.restfulclient==0.13.5
# lazr.uri==1.0.3
# lazy-object-proxy==1.4.3
# louis==3.5.0
# lxml==4.4.2
# macaroonbakery==1.1.3
# Mako==1.0.7
# Markdown==3.1.1
# MarkupSafe==1.0
# matplotlib==3.1.2
# mccabe==0.6.1
# mistune==0.8.3
# mock==3.0.5
# more-itertools==8.0.2
# natsort==7.0.0
# nbconvert==5.3.1
# nbformat==4.4.0
# netifaces==0.10.4
# networkx==2.4
# notebook==5.2.2
# numpy==1.17.4
# oauth==1.0.1
# oauthlib==3.1.0
# olefile==0.45.1
# opencv-contrib-python==4.1.2.30
# opencv-python==4.1.2.30
# opt-einsum==3.1.0
# packaging==19.2
# pandas==0.25.3
# pandocfilters==1.4.2
# pexpect==4.2.1
# pickleshare==0.7.4
# Pillow==6.2.1
# pipenv==2018.11.26
# pluggy==0.13.1
# portalocker==1.5.2
# prompt-toolkit==1.0.15
# protobuf==3.11.0
# py==1.8.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.7
# pycairo==1.16.2
# pycodestyle==2.5.0
# pycrypto==2.6.1
# pycups==1.9.73
# Pygments==2.2.0
# pygobject==3.26.1
# PyJWT==1.5.3
# pylint==2.4.4
# pylustrator==0.13.0
# pymacaroons==0.13.0
# PyNaCl==1.1.2
# pyparsing==2.4.5
# PyQt5==5.14.1
# PyQt5-sip==12.7.0
# pyRFC3339==1.0
# pytest==5.3.2
# python-apt==1.6.5+ubuntu0.3
# python-dateutil==2.8.1
# python-debian==0.1.32
# pytz==2019.3
# PyWavelets==1.1.1
# pyxdg==0.25
# PyYAML==5.2b1
# pyzmq==16.0.2
# qrcode==6.1
# QtAwesome==0.6.1
# QtPy==1.9.0
# reportlab==3.4.0
# requests==2.22.0
# requests-oauthlib==1.3.0
# requests-unixsocket==0.1.5
# rsa==4.0
# scikit-image==0.16.2
# scikit-learn==0.22
# scikit-plot==0.3.7
# scipy==1.3.3
# screen-resolution-extra==0.0.0
# SecretStorage==2.3.1
# simplegeneric==0.8.1
# simplejson==3.13.2
# six==1.13.0
# sklearn==0.0
# -e git+https://github.com/facebookresearch/slowfast@81fab7651ef6b17b04723f08e41ea54632434ee3#egg=slowfast
# svg.path==4.0.2
# svgutils==0.3.1
# system-service==0.3
# systemd-python==234
# tensorboard==2.0.2
# tensorboardX==1.9
# tensorflow-estimator==2.0.1
# tensorflow-gpu==2.0.0
# tensorflow-hub==0.7.0
# termcolor==1.1.0
# terminado==0.7
# testpath==0.3.1
# torch==1.3.1
# torchsummary==1.5.1
# torchvision==0.4.2
# tornado==4.5.3
# tqdm==4.40.0
# traitlets==4.3.2
# typed-ast==1.4.0
# ubuntu-drivers-common==0.0.0
# ufw==0.36
# unattended-upgrades==0.1
# urllib3==1.22
# usb-creator==0.3.3
# virtualenv==16.7.8
# virtualenv-clone==0.5.3
# wadllib==1.3.2
# wcwidth==0.1.7
# webencodings==0.5
# Werkzeug==0.16.0
# wrapt==1.11.2
# xkit==0.0.0
# yacs==0.1.6
# zipp==0.6.0
# zope.interface==4.3.2
